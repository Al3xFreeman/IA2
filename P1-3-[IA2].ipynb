# %%
import pandas as pd

# %%
data = pd.read_csv("countries.csv")
data.head()
# Out:
#            Country                               Region  Population  \
# 0     Afghanistan         ASIA (EX. NEAR EAST)             31056997
# 1         Albania   EASTERN EUROPE                          3581655
# 2         Algeria   NORTHERN AFRICA                        32930091
# 3  American Samoa   OCEANIA                                   57794
# 4         Andorra   WESTERN EUROPE                            71201
#
#    Area (sq. mi.)  Pop. Density (per sq. mi.)  Coastline (coast/area ratio)  \
# 0          647500                        48.0                          0.00
# 1           28748                       124.6                          1.26
# 2         2381740                        13.8                          0.04
# 3             199                       290.4                         58.29
# 4             468                       152.1                          0.00
#
#    Net migration  Infant mortality (per 1000 births)  GDP (USD per capita)  \
# 0          23.06                              163.07                 700.0
# 1          -4.93                               21.52                4500.0
# 2          -0.39                               31.00                6000.0
# 3         -20.71                                9.27                8000.0
# 4           6.60                                4.05               19000.0
#
#    Literacy (%)  Phones (per 1000)  Arable (%)  Crops (%)  Other (%)  Climate  \
# 0          36.0                3.2       12.13       0.22      87.65      1.0
# 1          86.5               71.2       21.09       4.42      74.49      3.0
# 2          70.0               78.1        3.22       0.25      96.53      1.0
# 3          97.0              259.5       10.00      15.00      75.00      2.0
# 4         100.0              497.2        2.22       0.00      97.78      3.0
#
#    Birthrate  Deathrate  Agriculture  Industry  Service
# 0      46.60      20.34        0.380     0.240    0.380
# 1      15.11       5.22        0.232     0.188    0.579
# 2      17.14       4.61        0.101     0.600    0.298
# 3      22.46       3.27          NaN       NaN      NaN
# 4       8.71       6.25          NaN       NaN      NaN

# %%
data.keys()
# Out:
# Index(['Country', 'Region', 'Population', 'Area (sq. mi.)',
#        'Pop. Density (per sq. mi.)', 'Coastline (coast/area ratio)',
#        'Net migration', 'Infant mortality (per 1000 births)',
#        'GDP (USD per capita)', 'Literacy (%)', 'Phones (per 1000)',
#        'Arable (%)', 'Crops (%)', 'Other (%)', 'Climate', 'Birthrate',
#        'Deathrate', 'Agriculture', 'Industry', 'Service'],
#       dtype='object')

# %% [markdown]
# ### Arreglando los datos:

# %%
data.drop("Region", axis=1)
data.describe()
# Out:
#          Population  Area (sq. mi.)  Pop. Density (per sq. mi.)  \
# count  2.270000e+02    2.270000e+02                  227.000000
# mean   2.874028e+07    5.982270e+05                  379.047137
# std    1.178913e+08    1.790282e+06                 1660.185825
# min    7.026000e+03    2.000000e+00                    0.000000
# 25%    4.376240e+05    4.647500e+03                   29.150000
# 50%    4.786994e+06    8.660000e+04                   78.800000
# 75%    1.749777e+07    4.418110e+05                  190.150000
# max    1.313974e+09    1.707520e+07                16271.500000
#
#        Coastline (coast/area ratio)  Net migration  \
# count                    227.000000     224.000000
# mean                      21.165330       0.038125
# std                       72.286863       4.889269
# min                        0.000000     -20.990000
# 25%                        0.100000      -0.927500
# 50%                        0.730000       0.000000
# 75%                       10.345000       0.997500
# max                      870.660000      23.060000
#
#        Infant mortality (per 1000 births)  GDP (USD per capita)  Literacy (%)  \
# count                          224.000000            226.000000    209.000000
# mean                            35.506964           9689.823009     82.838278
# std                             35.389899          10049.138513     19.722173
# min                              2.290000            500.000000     17.600000
# 25%                              8.150000           1900.000000     70.600000
# 50%                             21.000000           5550.000000     92.500000
# 75%                             55.705000          15700.000000     98.000000
# max                            191.190000          55100.000000    100.000000
#
#        Phones (per 1000)  Arable (%)   Crops (%)   Other (%)     Climate  \
# count         223.000000  225.000000  225.000000  225.000000  205.000000
# mean          236.061435   13.797111    4.564222   81.638311    2.139024
# std           227.991829   13.040402    8.361470   16.140835    0.699397
# min             0.200000    0.000000    0.000000   33.330000    1.000000
# 25%            37.800000    3.220000    0.190000   71.650000    2.000000
# 50%           176.200000   10.420000    1.030000   85.700000    2.000000
# 75%           389.650000   20.000000    4.440000   95.440000    3.000000
# max          1035.600000   62.110000   50.680000  100.000000    4.000000
#
#         Birthrate   Deathrate  Agriculture    Industry     Service
# count  224.000000  223.000000   212.000000  211.000000  212.000000
# mean    22.114732    9.241345     0.150844    0.282711    0.565283
# std     11.176716    4.990026     0.146798    0.138272    0.165841
# min      7.290000    2.290000     0.000000    0.020000    0.062000
# 25%     12.672500    5.910000     0.037750    0.193000    0.429250
# 50%     18.790000    7.840000     0.099000    0.272000    0.571000
# 75%     29.820000   10.605000     0.221000    0.341000    0.678500
# max     50.730000   29.740000     0.769000    0.906000    0.954000

# %%
data.isna().sum()
# Out:
# Country                                0
# Region                                 0
# Population                             0
# Area (sq. mi.)                         0
# Pop. Density (per sq. mi.)             0
# Coastline (coast/area ratio)           0
# Net migration                          3
# Infant mortality (per 1000 births)     3
# GDP (USD per capita)                   1
# Literacy (%)                          18
# Phones (per 1000)                      4
# Arable (%)                             2
# Crops (%)                              2
# Other (%)                              2
# Climate                               22
# Birthrate                              3
# Deathrate                              4
# Agriculture                           15
# Industry                              16
# Service                               15
# dtype: int64

# %%
data = data.dropna()
data.describe()
# Out:
#          Population  Area (sq. mi.)  Pop. Density (per sq. mi.)  \
# count  1.790000e+02    1.790000e+02                  179.000000
# mean   3.421415e+07    5.641830e+05                  294.805028
# std    1.317639e+08    1.395657e+06                 1379.352557
# min    1.347700e+04    2.800000e+01                    1.800000
# 25%    1.188580e+06    1.991500e+04                   26.800000
# 50%    6.940432e+06    1.184800e+05                   66.900000
# 75%    2.086014e+07    4.964410e+05                  164.700000
# max    1.313974e+09    9.631420e+06                16183.000000
#
#        Coastline (coast/area ratio)  Net migration  \
# count                    179.000000     179.000000
# mean                      16.495196      -0.206536
# std                       73.977601       4.751216
# min                        0.000000     -20.990000
# 25%                        0.090000      -1.315000
# 50%                        0.630000       0.000000
# 75%                        5.355000       0.395000
# max                      870.660000      23.060000
#
#        Infant mortality (per 1000 births)  GDP (USD per capita)  Literacy (%)  \
# count                          179.000000            179.000000    179.000000
# mean                            38.898156           9125.698324     81.944134
# std                             35.353003           9644.123141     19.837537
# min                              2.290000            500.000000     17.600000
# 25%                              9.990000           1800.000000     69.950000
# 50%                             24.310000           5100.000000     90.900000
# 75%                             64.605000          12950.000000     97.800000
# max                            163.070000          37800.000000    100.000000
#
#        Phones (per 1000)  Arable (%)   Crops (%)   Other (%)     Climate  \
# count         179.000000  179.000000  179.000000  179.000000  179.000000
# mean          208.151955   14.000447    4.440838   81.558212    2.108939
# std           210.121875   13.152405    8.090331   16.103748    0.697611
# min             0.200000    0.000000    0.000000   33.330000    1.000000
# 25%            27.100000    3.675000    0.230000   72.825000    2.000000
# 50%           137.100000   10.530000    1.030000   86.070000    2.000000
# 75%           335.000000   20.000000    4.600000   94.810000    2.500000
# max           898.000000   62.110000   48.960000  100.000000    4.000000
#
#         Birthrate   Deathrate  Agriculture    Industry     Service
# count  179.000000  179.000000   179.000000  179.000000  179.000000
# mean    23.067486    9.465140     0.156905    0.288028    0.554508
# std     11.287207    5.210083     0.151343    0.140310    0.165670
# min      7.290000    2.410000     0.000000    0.032000    0.062000
# 25%     13.890000    5.795000     0.039000    0.197000    0.424500
# 50%     20.460000    7.840000     0.101000    0.274000    0.559000
# 75%     32.315000   11.660000     0.233000    0.349000    0.668500
# max     50.730000   29.740000     0.769000    0.906000    0.954000

# %% [markdown]
# ### Describiendo los datos:
#
#     - Nombre del conjunto de datos
#     - Breve descripción del problema que describe
#     - Tabla con el nombre y tipo de las variables
#     - Tabla de estadísticos descriptivos de cada variable

# %% [markdown]
# El conjunto de datos utiliza el csv "countries.csv"
#
# Dicho conjunto de datos recoge información de diversos países, desde la población hasta el alfabetismo de la población, pasando por el número de móviles por 1000 habitantes o el porcentaje de tierra cultibable.
#
# Como podemos ver es un conjunto de datos bastante detallado, mediante el cual intentaremos predeir el valor del GDP de cada país mediante regresión.
#
# A continuación están dos tablas, una de ellas con la información estadística de las variables y la siguiente con los tipos de las variables

# %%
data.describe()
# Out:
#          Population  Area (sq. mi.)  Pop. Density (per sq. mi.)  \
# count  1.790000e+02    1.790000e+02                  179.000000
# mean   3.421415e+07    5.641830e+05                  294.805028
# std    1.317639e+08    1.395657e+06                 1379.352557
# min    1.347700e+04    2.800000e+01                    1.800000
# 25%    1.188580e+06    1.991500e+04                   26.800000
# 50%    6.940432e+06    1.184800e+05                   66.900000
# 75%    2.086014e+07    4.964410e+05                  164.700000
# max    1.313974e+09    9.631420e+06                16183.000000
#
#        Coastline (coast/area ratio)  Net migration  \
# count                    179.000000     179.000000
# mean                      16.495196      -0.206536
# std                       73.977601       4.751216
# min                        0.000000     -20.990000
# 25%                        0.090000      -1.315000
# 50%                        0.630000       0.000000
# 75%                        5.355000       0.395000
# max                      870.660000      23.060000
#
#        Infant mortality (per 1000 births)  GDP (USD per capita)  Literacy (%)  \
# count                          179.000000            179.000000    179.000000
# mean                            38.898156           9125.698324     81.944134
# std                             35.353003           9644.123141     19.837537
# min                              2.290000            500.000000     17.600000
# 25%                              9.990000           1800.000000     69.950000
# 50%                             24.310000           5100.000000     90.900000
# 75%                             64.605000          12950.000000     97.800000
# max                            163.070000          37800.000000    100.000000
#
#        Phones (per 1000)  Arable (%)   Crops (%)   Other (%)     Climate  \
# count         179.000000  179.000000  179.000000  179.000000  179.000000
# mean          208.151955   14.000447    4.440838   81.558212    2.108939
# std           210.121875   13.152405    8.090331   16.103748    0.697611
# min             0.200000    0.000000    0.000000   33.330000    1.000000
# 25%            27.100000    3.675000    0.230000   72.825000    2.000000
# 50%           137.100000   10.530000    1.030000   86.070000    2.000000
# 75%           335.000000   20.000000    4.600000   94.810000    2.500000
# max           898.000000   62.110000   48.960000  100.000000    4.000000
#
#         Birthrate   Deathrate  Agriculture    Industry     Service
# count  179.000000  179.000000   179.000000  179.000000  179.000000
# mean    23.067486    9.465140     0.156905    0.288028    0.554508
# std     11.287207    5.210083     0.151343    0.140310    0.165670
# min      7.290000    2.410000     0.000000    0.032000    0.062000
# 25%     13.890000    5.795000     0.039000    0.197000    0.424500
# 50%     20.460000    7.840000     0.101000    0.274000    0.559000
# 75%     32.315000   11.660000     0.233000    0.349000    0.668500
# max     50.730000   29.740000     0.769000    0.906000    0.954000

# %%
data.dtypes
# Out:
# Country                                object
# Region                                 object
# Population                              int64
# Area (sq. mi.)                          int64
# Pop. Density (per sq. mi.)            float64
# Coastline (coast/area ratio)          float64
# Net migration                         float64
# Infant mortality (per 1000 births)    float64
# GDP (USD per capita)                  float64
# Literacy (%)                          float64
# Phones (per 1000)                     float64
# Arable (%)                            float64
# Crops (%)                             float64
# Other (%)                             float64
# Climate                               float64
# Birthrate                             float64
# Deathrate                             float64
# Agriculture                           float64
# Industry                              float64
# Service                               float64
# dtype: object

# %%
correl=data.corr()
correl['GDP (USD per capita)']
# Out:
# Population                           -0.033618
# Area (sq. mi.)                        0.068356
# Pop. Density (per sq. mi.)            0.190122
# Coastline (coast/area ratio)          0.035815
# Net migration                         0.378790
# Infant mortality (per 1000 births)   -0.639090
# GDP (USD per capita)                  1.000000
# Literacy (%)                          0.522880
# Phones (per 1000)                     0.883520
# Arable (%)                            0.046465
# Crops (%)                            -0.207844
# Other (%)                             0.066445
# Climate                               0.360567
# Birthrate                            -0.658795
# Deathrate                            -0.247562
# Agriculture                          -0.616919
# Industry                              0.032855
# Service                               0.536551
# Name: GDP (USD per capita), dtype: float64

# %% [markdown]
# La correlación con el GDP está claramente presente en aquellos paises que están más desarrollados, que que es inversamente proporcional a métricas como la mortalidad infantil, tienen menor número de nacimientos o no dependen en una economñía basada en la agricultura. También una métrica que indica un alto GDP es el número de móviles por 1000 habitantes, ya que nos indica que en dicho pais habrá un mayor consumo de bienes que no son de primera necesidad.
#
# Otros elementos como el porcentaje de gente con educación parecen ser también bastante relevantes.

# %%
import seaborn as sns; sns.set(style="ticks", color_codes=True)
g = sns.pairplot(data)

# %% [markdown]
# ### Filtrar con coeficiente de correlación con el GDP:

# %%
correl[abs(correl['GDP (USD per capita)']) > 0.5]['GDP (USD per capita)']
# Out:
# Infant mortality (per 1000 births)   -0.639090
# GDP (USD per capita)                  1.000000
# Literacy (%)                          0.522880
# Phones (per 1000)                     0.883520
# Birthrate                            -0.658795
# Agriculture                          -0.616919
# Service                               0.536551
# Name: GDP (USD per capita), dtype: float64

# %%
data['GDP (USD per capita)']
# Out:
# 0        700.0
# 1       4500.0
# 2       6000.0
# 6       8600.0
# 7      11000.0
# 8      11200.0
# 9       3500.0
# 10     28000.0
# 11     29000.0
# 12     30000.0
# 13      3400.0
# 14     16700.0
# 15     16900.0
# 16      1900.0
# 17     15700.0
# 18      6100.0
# 19     29100.0
# 20      4900.0
# 21      1100.0
# 22     36000.0
# 23      1300.0
# 24      2400.0
# 26      9000.0
# 27      7600.0
# 28     16000.0
# 29     18600.0
# 30      7600.0
# 31      1100.0
# 32      1800.0
# 33       600.0
#         ...
# 190    22000.0
# 191     3700.0
# 192     1900.0
# 193     4000.0
# 194     4900.0
# 195    26800.0
# 196    32700.0
# 197     3300.0
# 198    23400.0
# 199     1000.0
# 201     7400.0
# 202     1500.0
# 203     2200.0
# 204     9500.0
# 205     6900.0
# 206     6700.0
# 207     5800.0
# 210     1400.0
# 211     5400.0
# 212    23200.0
# 213    27700.0
# 214    37800.0
# 215    12800.0
# 216     1700.0
# 217     2900.0
# 218     4800.0
# 219     2500.0
# 224      800.0
# 225      800.0
# 226     1900.0
# Name: GDP (USD per capita), Length: 179, dtype: float64

# %% [markdown]
# ### Normalizar y estandarizar datos:
#
#     Debido a que estamos trabajando con una gran variedad de datos que recogen mediciones de datos muy diversos y sobre distintas escalas es necesario adaptar los datos para que ninguna variable haga que el modelo pierda toda la precisión que podría llegar a tener

# %%
from sklearn.preprocessing import StandardScaler

countryList = data['Country']
aux = data.drop(["Country", "Region"], axis=1)

aux

# Transformamos las variables de entrada
scaler_x = StandardScaler()
scaler_x.fit(aux)
data_scaled=scaler_x.transform(aux)

df_scaled = pd.DataFrame(data_scaled, columns=aux.keys())
df_scaled['GDP (USD per capita)']

# Y también transformamos la variable de salida
scaler_y = StandardScaler()
scaler_y.fit(data['GDP (USD per capita)'].to_numpy().reshape(-1, 1)) # Como es una sola variable es necesario ponerlo en modo columna
target_scaled=scaler_y.transform(data['GDP (USD per capita)'].to_numpy().reshape(-1, 1))

# %%
target_scaled
# Out:
# array([[-8.76112089e-01],
#        [-4.80984491e-01],
#        [-3.25013071e-01],
#        [-5.46626094e-02],
#        [ 1.94891663e-01],
#        [ 2.15687852e-01],
#        [-5.84965438e-01],
#        [ 1.96256776e+00],
#        [ 2.06654870e+00],
#        [ 2.17052965e+00],
#        [-5.95363532e-01],
#        [ 7.87583059e-01],
#        [ 8.08379248e-01],
#        [-7.51334952e-01],
#        [ 6.83602112e-01],
#        [-3.14614976e-01],
#        [ 2.07694680e+00],
#        [-4.39392112e-01],
#        [-8.34519710e-01],
#        [ 2.79441533e+00],
#        [-8.13723521e-01],
#        [-6.99344479e-01],
#        [-1.30702307e-02],
#        [-1.58643556e-01],
#        [ 7.14796396e-01],
#        [ 9.85146858e-01],
#        [-1.58643556e-01],
#        [-8.34519710e-01],
#        [-7.61733047e-01],
#        [-8.86510183e-01],
#        [-7.51334952e-01],
#        [-7.61733047e-01],
#        [-8.03325426e-01],
#        [ 2.69043438e+00],
#        [-8.34519710e-01],
#        [-8.24121615e-01],
#        [ 8.05126213e-02],
#        [-4.28994018e-01],
#        [-2.93818787e-01],
#        [-8.76112089e-01],
#        [-8.76112089e-01],
#        [-8.76112089e-01],
#        [-2.67213606e-03],
#        [-8.03325426e-01],
#        [-6.47354006e-01],
#        [ 6.83602112e-01],
#        [ 2.28490869e+00],
#        [-8.13723521e-01],
#        [-3.87401639e-01],
#        [-3.25013071e-01],
#        [-6.05761627e-01],
#        [-5.32974964e-01],
#        [-4.49790207e-01],
#        [-6.68150195e-01],
#        [-8.76112089e-01],
#        [ 3.30066893e-01],
#        [-3.87401639e-01],
#        [ 1.46345921e+00],
#        [ 1.93137347e+00],
#        [ 2.98158104e+00],
#        [ 3.82057367e-01],
#        [-7.72131142e-01],
#        [-6.47354006e-01],
#        [-4.49790207e-01],
#        [-6.88946384e-01],
#        [-8.65713994e-01],
#        [-8.65713994e-01],
#        [-7.51334952e-01]])

# %%
aux.head()
# Out:
#    Population  Area (sq. mi.)  Pop. Density (per sq. mi.)  \
# 0    31056997          647500                        48.0
# 1     3581655           28748                       124.6
# 2    32930091         2381740                        13.8
# 6       13477             102                       132.1
# 7       69108             443                       156.0
#
#    Coastline (coast/area ratio)  Net migration  \
# 0                          0.00          23.06
# 1                          1.26          -4.93
# 2                          0.04          -0.39
# 6                         59.80          10.76
# 7                         34.54          -6.15
#
#    Infant mortality (per 1000 births)  GDP (USD per capita)  Literacy (%)  \
# 0                              163.07                 700.0          36.0
# 1                               21.52                4500.0          86.5
# 2                               31.00                6000.0          70.0
# 6                               21.03                8600.0          95.0
# 7                               19.46               11000.0          89.0
#
#    Phones (per 1000)  Arable (%)  Crops (%)  Other (%)  Climate  Birthrate  \
# 0                3.2       12.13       0.22      87.65      1.0      46.60
# 1               71.2       21.09       4.42      74.49      3.0      15.11
# 2               78.1        3.22       0.25      96.53      1.0      17.14
# 6              460.0        0.00       0.00     100.00      2.0      14.17
# 7              549.9       18.18       4.55      77.27      2.0      16.93
#
#    Deathrate  Agriculture  Industry  Service
# 0      20.34        0.380     0.240    0.380
# 1       5.22        0.232     0.188    0.579
# 2       4.61        0.101     0.600    0.298
# 6       5.34        0.040     0.180    0.780
# 7       5.37        0.038     0.220    0.743

# %%
df_scaled.head()
# Out:
#    Population  Area (sq. mi.)  Pop. Density (per sq. mi.)  \
# 0   -0.024028        0.059865                   -0.179430
# 1   -0.233132       -0.384720                   -0.123741
# 2   -0.009772        1.305948                   -0.204294
# 3   -0.260288       -0.405302                   -0.118288
# 4   -0.259865       -0.405057                   -0.100913
#
#    Coastline (coast/area ratio)  Net migration  \
# 0                     -0.223601       4.910701
# 1                     -0.206521      -0.996948
# 2                     -0.223059      -0.038722
# 3                      0.587019       2.314628
# 4                      0.244607      -1.254444
#
#    Infant mortality (per 1000 births)  GDP (USD per capita)  Literacy (%)  \
# 0                            3.522194             -0.876112     -2.322517
# 1                           -0.492940             -0.480984      0.230303
# 2                           -0.224035             -0.325013     -0.603787
# 3                           -0.506839             -0.054663      0.659986
# 4                           -0.551373              0.194892      0.356680
#
#    Phones (per 1000)  Arable (%)  Crops (%)  Other (%)   Climate  Birthrate  \
# 0          -0.978132   -0.142612  -0.523177   0.379345 -1.594082   2.090732
# 1          -0.653602    0.540543  -0.002583  -0.440148  1.280887  -0.706978
# 2          -0.620672   -0.821955  -0.519459   0.932316 -1.594082  -0.526624
# 3           1.201943   -1.067464  -0.550447   1.148398 -0.156597  -0.790492
# 4           1.630990    0.318670   0.013531  -0.267034 -0.156597  -0.545281
#
#    Deathrate  Agriculture  Industry   Service
# 0   2.093127     1.478239 -0.343260 -1.056306
# 1  -0.817079     0.497583 -0.714908  0.148249
# 2  -0.934488    -0.370430  2.229691 -1.552656
# 3  -0.793982    -0.774619 -0.772085  1.364910
# 4  -0.788208    -0.787871 -0.486202  1.140947

# %% [markdown]
# ### Vamos a empesar con la regresión:
#
# Hay unas cuantas variables, si veo que el error es muy grande cogemos solo las que tengan un coeficiente de correlación elevado

# %% [markdown]
# # Vamos a aser primero como lo tiene el en clase, luego hago lo que tenemos que hacer de la práctica

# %%
data['GDP (USD per capita)'].hist()

# %% [markdown]
# La mayoría de los valores se encuentran en la parte baja, probablemente esto signifique que al tener una gran cantidad de países con un GDP bajo el modelo sea mejor a la hora de predecir esos resultados, mientras que con los países con un meyor GDP lo haga peor

# %%
from sklearn.neural_network import MLPRegressor
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error
import numpy as np


regul_param_range = 10.0 ** -np.arange(-1, 4) 

cv_scores_mean=[]
cv_scores_std=[]

for regul_param in regul_param_range:
    # aumentamos el parámetro max_iter hasta que converja
    mlp=MLPRegressor(hidden_layer_sizes=(100, ), activation='relu', solver='adam', alpha=regul_param, batch_size=100, 
             learning_rate='constant', learning_rate_init=0.001, max_iter=350, random_state=333)
    
    # El error es neg_mean_squared_error el MSE en negativo!! Más pequeño peor.
    scores = cross_val_score(mlp, df_scaled, target_scaled.ravel(), cv=5, scoring='neg_mean_squared_error')
    
    cv_scores_mean.append(scores.mean())
    cv_scores_std.append(scores.std())

# %%
import matplotlib.pyplot as plt

# Dibujamos la línea de la exactitud media en las partes de test
# Como el 
plt.plot(np.log10(regul_param_range), cv_scores_mean, color="g", label="Test")

# Dibujamos la banda de la desviación típica
lower_limit=np.array(cv_scores_mean)-np.array(cv_scores_std)
upper_limit=np.array(cv_scores_mean)+np.array(cv_scores_std)
plt.fill_between(np.log10(regul_param_range), lower_limit, upper_limit, color="#DDDDDD")

# Creamos el gráfico
plt.title("Curva de aprendizaje")
plt.xlabel("Regularización 10^{-X}"), plt.ylabel("negative MSE"), plt.legend(loc="best")
plt.tight_layout()
plt.show()

# %% [markdown]
# El mejor está en 0? Pues bien, no?

# %%
from sklearn.model_selection import cross_val_predict


regul_param=10**-2

#mlp=MLPRegressor(hidden_layer_sizes=(100, ), activation='relu', solver='adam', alpha=regul_param, batch_size=100, 
#             learning_rate='constant', learning_rate_init=0.001, max_iter=350, random_state=333)
    

predicts_scaled = cross_val_predict(mlp, df_scaled, target_scaled.ravel(), cv=5)


# escalamos las predicciones para que estén en la escala original
predicts=scaler_y.inverse_transform(predicts_scaled)

# %% [markdown]
# ## NO entiendo por qué "scaler_y.inverse_transform" no escala de nuevo las variables predichas

# %%
predicts_scaled, predicts
# Out:
# (array([-0.71635502, -0.74509242, -0.32632207,  0.39267565,  0.1058743 ,
#          0.17913892, -0.81583583,  1.95616199,  1.58738909,  2.0813653 ,
#         -0.66519758,  0.55764694,  0.69656374, -0.4394932 ,  0.94108335,
#         -0.01318955,  1.99355174, -0.40020915, -0.83410005,  2.47518621,
#         -0.75036586, -0.69047715, -0.03365155, -0.25367906,  1.03030742,
#          1.09636123, -0.13897492, -0.89536293, -0.78252656, -0.89635428,
#         -0.77007542, -0.68036778, -0.90075818,  2.58707173, -0.924654  ,
#         -0.84439893,  0.27087836,  0.16238118, -0.32155252, -0.79748211,
# 28     16000.0
# 29     18600.0
# 30      7600.0
# 31      1100.0
# 32      1800.0
# 33       600.0
#         ...
# 190    22000.0
# 191     3700.0
# 192     1900.0
# 193     4000.0
# 194     4900.0
# 195    26800.0
# 196    32700.0
# 197     3300.0
# 198    23400.0
# 199     1000.0
# 201     7400.0
# 202     1500.0
# 203     2200.0
# 204     9500.0
# 205     6900.0
# 206     6700.0
# 207     5800.0
# 210     1400.0
# 211     5400.0
# 212    23200.0
# 213    27700.0
# 214    37800.0
# 215    12800.0
# 216     1700.0
# 217     2900.0
# 218     4800.0
# 219     2500.0
# 224      800.0
# 225      800.0
# 226     1900.0
# Name: GDP (USD per capita), Length: 179, dtype: float64

# %%
# Dibujamos el histograma de los errores
fig1 = plt.figure()
ax1 = plt.axes()
ax1.hist(np.abs(data['GDP (USD per capita)'] - predicts))  # np.abs(boston.target - predicts) es el error en cada ejemplo

plt.title('Distribución del error en valor absoluto')
plt.show()

# %%
predicts
# Out:
# array([-0.71635502, -0.74509242, -0.32632207,  0.39267565,  0.1058743 ,
#         0.17913892, -0.81583583,  1.95616199,  1.58738909,  2.0813653 ,
#        -0.66519758,  0.55764694,  0.69656374, -0.4394932 ,  0.94108335,
#        -0.01318955,  1.99355174, -0.40020915, -0.83410005,  2.47518621,
#        -0.75036586, -0.69047715, -0.03365155, -0.25367906,  1.03030742,
#         1.09636123, -0.13897492, -0.89536293, -0.78252656, -0.89635428,
#        -0.77007542, -0.68036778, -0.90075818,  2.58707173, -0.924654  ,
#        -0.84439893,  0.27087836,  0.16238118, -0.32155252, -0.79748211,
#        -0.89953279, -0.94628279,  0.07368929, -0.64821923, -0.63920889,
#         0.5987234 ,  1.83185603, -0.63636444, -0.25734641, -0.41887009,
#        -0.57663199, -0.40126547, -0.44375517, -0.75835271, -0.70419456,
#         0.42932347, -0.83907994, -0.49238866,  1.9848354 ,  1.81479107,
#         0.04007615,  0.8230995 , -0.53515302, -0.82065871, -0.72071452,
#         1.77016972, -0.74188894,  1.18429437, -0.47584204, -0.049492  ,
#        -0.55605782, -0.79741161, -0.91186143, -0.41652267, -0.64012032,
#        -0.66607377,  2.0291711 ,  0.56244461,  2.14397004, -0.93726924,
#        -0.54304387, -0.1968998 , -0.84382723,  2.10941317,  1.20615921,
#        -0.62294693,  1.85106178, -0.2841573 , -0.33012708, -0.78542813,
#        -0.8436226 ,  1.04739051,  0.9594912 , -0.71155874, -0.78651215,
#         0.23562824, -0.80740405, -1.24596493,  1.59700437,  0.9494146 ,
#        -0.8726513 , -0.92640555, -0.19053028, -0.55584737, -0.87285586,
#        -0.72983314,  0.47313968, -0.63559049,  0.20998892, -0.04657832,
#        -0.98380964, -0.72259415, -0.82789514, -0.27197704,  1.98802286,
#         0.36650374,  0.36888033,  1.37163407, -0.82237489, -0.82414352,
#        -0.99474045,  2.68548868, -0.02026873, -0.54400871,  0.22980625,
#        -0.35014661, -0.65178503, -0.56158945, -0.52836379, -0.57947264,
#         0.31214145,  0.97222937,  1.00553691,  1.24323577, -0.13186965,
#        -0.22798647, -0.95915049,  0.0931741 , -0.19264685, -0.61405487,
#        -0.43025721, -0.75378877, -0.06577179, -0.84894853, -0.08252519,
#        -0.81044007,  1.61428349, -0.79049093,  0.12051087,  1.129623  ,
#        -0.5259238 , -0.80425315, -0.66073391, -0.44866191,  2.0257074 ,
#         2.45464518, -0.44893138,  1.45486131, -0.91415679, -0.30028414,
#        -0.74738871, -0.8803266 , -0.09389074, -0.32442938, -0.13145954,
#        -0.44770959, -0.80655917, -0.50425829,  1.30559182,  1.99996978,
#         2.73395991,  0.50379879, -0.62646791, -0.66140441, -0.36491705,
#        -0.40913137, -0.72423149, -0.85756675, -0.64434499])

# %%
data['GDP (USD per capita)']
# Out:
# 0        700.0
# 1       4500.0
# 2       6000.0
# 6       8600.0
# 7      11000.0
# 8      11200.0
# 9       3500.0
# 10     28000.0
# 11     29000.0
# 12     30000.0
# 13      3400.0
# 14     16700.0
# 15     16900.0
# 16      1900.0
# 17     15700.0
# 18      6100.0
# 19     29100.0
# 20      4900.0
# 21      1100.0
# 22     36000.0
# 23      1300.0
# 24      2400.0
# 26      9000.0
# 27      7600.0
# 28     16000.0
# 29     18600.0
# 30      7600.0
# 31      1100.0
# 32      1800.0
# 33       600.0
#         ...
# 190    22000.0
# 191     3700.0
# 192     1900.0
# 193     4000.0
# 194     4900.0
# 195    26800.0
# 196    32700.0
# 197     3300.0
# 198    23400.0
# 199     1000.0
# 201     7400.0
# 202     1500.0
# 203     2200.0
# 204     9500.0
# 205     6900.0
# 206     6700.0
# 207     5800.0
# 210     1400.0
# 211     5400.0
# 212    23200.0
# 213    27700.0
# 214    37800.0
# 215    12800.0
# 216     1700.0
# 217     2900.0
# 218     4800.0
# 219     2500.0
# 224      800.0
# 225      800.0
# 226     1900.0
# Name: GDP (USD per capita), Length: 179, dtype: float64

# %%
fig2 = plt.figure()
ax2 = plt.axes()

# dibujamos los errores: la distancia a la recta indica el nivel de error
ax2.scatter(data['GDP (USD per capita)'], predicts) 
# Pintamos la referencia de la predicción perfecta
ax2.plot(data['GDP (USD per capita)'], data['GDP (USD per capita)'], color='k') 

plt.title('Y Vs Y_pred')
plt.show()

# %% [markdown]
# # Ahora si, lo que tenemo k aser d la praktika

# %% [markdown]
# #### Buscamos el mejor coeficiente de regularización usando validación cruzada

# %%
from sklearn.neural_network import MLPRegressor
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error
import numpy as np


regul_param_range = 10.0 ** -np.arange(1, 6) 

cv_scores_mean1=[]
cv_scores_std1=[]

for regul_param in regul_param_range:
    # aumentamos el parámetro max_iter hasta que converja
    mlp1=MLPRegressor(hidden_layer_sizes=(200, ), activation='relu', solver='adam', alpha=regul_param, batch_size=100, 
             learning_rate='constant', learning_rate_init=0.001, max_iter=350, random_state=333)
    
    # El error es neg_mean_squared_error el MSE en negativo!! Más pequeño peor.
    scores1 = cross_val_score(mlp1, df_scaled, target_scaled.ravel(), cv=5, scoring='neg_mean_squared_error')
    
    cv_scores_mean1.append(scores1.mean())
    cv_scores_std1.append(scores1.std())

# %%
regul_param_range = 10.0 ** -np.arange(1, 6) 

cv_scores_mean2=[]
cv_scores_std2=[]

for regul_param in regul_param_range:
    # aumentamos el parámetro max_iter hasta que converja
    mlp2=MLPRegressor(hidden_layer_sizes=(50,50, ), activation='relu', solver='adam', alpha=regul_param, batch_size=100, 
             learning_rate='constant', learning_rate_init=0.001, max_iter=350, random_state=333)
    
    # El error es neg_mean_squared_error el MSE en negativo!! Más pequeño peor.
    scores2 = cross_val_score(mlp2, df_scaled, target_scaled.ravel(), cv=5, scoring='neg_mean_squared_error')
    
    cv_scores_mean2.append(scores2.mean())
    cv_scores_std2.append(scores2.std())

# %%
# Dibujamos la línea de la exactitud media en las partes de test
# Como el 
plt.plot(np.log10(regul_param_range), cv_scores_mean1, color="g", label="Test")

# Dibujamos la banda de la desviación típica
lower_limit=np.array(cv_scores_mean1)-np.array(cv_scores_std1)
upper_limit=np.array(cv_scores_mean1)+np.array(cv_scores_std1)
plt.fill_between(np.log10(regul_param_range), lower_limit, upper_limit, color="#DDDDDD")

# Creamos el gráfico
plt.title("Curva de aprendizaje")
plt.xlabel("Regularización 10^{-X}"), plt.ylabel("negative MSE"), plt.legend(loc="best")
plt.tight_layout()
plt.show()

# %%
# Dibujamos la línea de la exactitud media en las partes de test
# Como el 
plt.plot(np.log10(regul_param_range), cv_scores_mean2, color="g", label="Test")

# Dibujamos la banda de la desviación típica
lower_limit=np.array(cv_scores_mean2)-np.array(cv_scores_std2)
upper_limit=np.array(cv_scores_mean2)+np.array(cv_scores_std2)
plt.fill_between(np.log10(regul_param_range), lower_limit, upper_limit, color="#DDDDDD")

# Creamos el gráfico
plt.title("Curva de aprendizaje")
plt.xlabel("Regularización 10^{-X}"), plt.ylabel("negative MSE"), plt.legend(loc="best")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Explicar pork el de las capas ocultas es mejor
#
# El de las capas ocultas es mejor ya que aunque haya un menir número de neuronas, hay un número superior de conexiones, esto nos ayuda a descubrir más patrones y conexiones entre variables. Con una sola capa de neuronas muchas de estas relaciones no se conseguirán. Esto puede llegar a ser un problema, ya que puede crear overfitting o identificar relaciones que no existen

# %% [markdown]
# ### Espero que funcione bien la transformada inversa de los datos para poder intentar ver bien cual es el pais de cada uno, en base a eso luego intentar hacer lo que solo coger las variables que tuvieran un coeficiente de correlación alto

# %%
from sklearn.model_selection import cross_val_predict

predicts_scaled2 = cross_val_predict(mlp2, df_scaled, target_scaled.ravel(), cv=5)

# escalamos las predicciones para que estén en la escala original
predicts2=scaler_y.inverse_transform(predicts_scaled2)

# %%
fig2 = plt.figure()
ax2 = plt.axes()

# dibujamos los errores: la distancia a la recta indica el nivel de error
ax2.scatter(data['GDP (USD per capita)'], predicts2) 
# Pintamos la referencia de la predicción perfecta
ax2.plot(data['GDP (USD per capita)'], data['GDP (USD per capita)'], color='k') 

plt.title('Y Vs Y_pred')
plt.show()

# %%
from sklearn.model_selection import cross_val_predict

predicts_scaled1 = cross_val_predict(mlp1, df_scaled, target_scaled.ravel(), cv=5)

# escalamos las predicciones para que estén en la escala original
predicts1=scaler_y.inverse_transform(predicts_scaled1)

# %%
fig2 = plt.figure()
ax2 = plt.axes()

# dibujamos los errores: la distancia a la recta indica el nivel de error
ax2.scatter(data['GDP (USD per capita)'], predicts1) 
# Pintamos la referencia de la predicción perfecta
ax2.plot(data['GDP (USD per capita)'], data['GDP (USD per capita)'], color='k') 

plt.title('Y Vs Y_pred')
plt.show()
