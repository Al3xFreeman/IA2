# %% [markdown]
# # PARTE 1: Agrupamiento o Clustering

# %% [markdown]
# ### 1) Datos
# - Nombre del conjunto de datos: USArrests.csv.
# - Descripción del problema: Agrega información sobre los arrestos en cada estado de EEUU pudiendo ser estos: asesinatos,   asaltos o violaciones por 100000 habitantes.
# - Tabla con el nombre y tipo de las variables:

# %%
import pandas as pd
data = pd.read_csv("USArrests.csv")
data.keys()
# Out:
# Index(['Unnamed: 0', 'Murder', 'Assault', 'UrbanPop', 'Rape'], dtype='object')

# %%
data
# Out:
#         Unnamed: 0  Murder  Assault  UrbanPop  Rape
# 0          Alabama    13.2      236        58  21.2
# 1           Alaska    10.0      263        48  44.5
# 2          Arizona     8.1      294        80  31.0
# 3         Arkansas     8.8      190        50  19.5
# 4       California     9.0      276        91  40.6
# 5         Colorado     7.9      204        78  38.7
# 6      Connecticut     3.3      110        77  11.1
# 7         Delaware     5.9      238        72  15.8
# 8          Florida    15.4      335        80  31.9
# 9          Georgia    17.4      211        60  25.8
# 10          Hawaii     5.3       46        83  20.2
# 11           Idaho     2.6      120        54  14.2
# 12        Illinois    10.4      249        83  24.0
# 13         Indiana     7.2      113        65  21.0
# 14            Iowa     2.2       56        57  11.3
# 15          Kansas     6.0      115        66  18.0
# 16        Kentucky     9.7      109        52  16.3
# 17       Louisiana    15.4      249        66  22.2
# 18           Maine     2.1       83        51   7.8
# 19        Maryland    11.3      300        67  27.8
# 20   Massachusetts     4.4      149        85  16.3
# 21        Michigan    12.1      255        74  35.1
# 22       Minnesota     2.7       72        66  14.9
# 23     Mississippi    16.1      259        44  17.1
# 24        Missouri     9.0      178        70  28.2
# 25         Montana     6.0      109        53  16.4
# 26        Nebraska     4.3      102        62  16.5
# 27          Nevada    12.2      252        81  46.0
# 28   New Hampshire     2.1       57        56   9.5
# 29      New Jersey     7.4      159        89  18.8
# 30      New Mexico    11.4      285        70  32.1
# 31        New York    11.1      254        86  26.1
# 32  North Carolina    13.0      337        45  16.1
# 33    North Dakota     0.8       45        44   7.3
# 34            Ohio     7.3      120        75  21.4
# 35        Oklahoma     6.6      151        68  20.0
# 36          Oregon     4.9      159        67  29.3
# 37    Pennsylvania     6.3      106        72  14.9
# 38    Rhode Island     3.4      174        87   8.3
# 39  South Carolina    14.4      279        48  22.5
# 40    South Dakota     3.8       86        45  12.8
# 41       Tennessee    13.2      188        59  26.9
# 42           Texas    12.7      201        80  25.5
# 43            Utah     3.2      120        80  22.9
# 44         Vermont     2.2       48        32  11.2
# 45        Virginia     8.5      156        63  20.7
# 46      Washington     4.0      145        73  26.2
# 47   West Virginia     5.7       81        39   9.3
# 48       Wisconsin     2.6       53        66  10.8
# 49         Wyoming     6.8      161        60  15.6

# %% [markdown]
# - Tabla de estadísticos descriptivos de cada variable:

# %%
data.describe()
# Out:
#          Murder     Assault   UrbanPop       Rape
# count  50.00000   50.000000  50.000000  50.000000
# mean    7.78800  170.760000  65.540000  21.232000
# std     4.35551   83.337661  14.474763   9.366385
# min     0.80000   45.000000  32.000000   7.300000
# 25%     4.07500  109.000000  54.500000  15.075000
# 50%     7.25000  159.000000  66.000000  20.100000
# 75%    11.25000  249.000000  77.750000  26.175000
# max    17.40000  337.000000  91.000000  46.000000

# %%
data['Murder'].describe()
# Out:
# count    50.00000
# mean      7.78800
# std       4.35551
# min       0.80000
# 25%       4.07500
# 50%       7.25000
# 75%      11.25000
# max      17.40000
# Name: Murder, dtype: float64

# %%
data['Assault'].describe()
# Out:
# count     50.000000
# mean     170.760000
# std       83.337661
# min       45.000000
# 25%      109.000000
# 50%      159.000000
# 75%      249.000000
# max      337.000000
# Name: Assault, dtype: float64

# %%
data['Rape'].describe()
# Out:
# count    50.000000
# mean     21.232000
# std       9.366385
# min       7.300000
# 25%      15.075000
# 50%      20.100000
# 75%      26.175000
# max      46.000000
# Name: Rape, dtype: float64

# %%
# Añadimos una columna para clasificar los estados en peligrosos o seguros.
# Para ello vamos hacer una función que clasifique cada estado en peligroso o seguro segun el numero de asesinatos.
data['Safety'] = None
data.loc[data['Murder'] >= data.describe()['Murder']['mean'], 'Safety'] = 'Dangerous'
data.loc[data['Murder'] < data.describe()['Murder']['mean'], 'Safety'] = 'Safe'
data
# Out:
#         Unnamed: 0  Murder  Assault  UrbanPop  Rape     Safety
# 0          Alabama    13.2      236        58  21.2  Dangerous
# 1           Alaska    10.0      263        48  44.5  Dangerous
# 2          Arizona     8.1      294        80  31.0  Dangerous
# 3         Arkansas     8.8      190        50  19.5  Dangerous
# 4       California     9.0      276        91  40.6  Dangerous
# 5         Colorado     7.9      204        78  38.7  Dangerous
# 6      Connecticut     3.3      110        77  11.1       Safe
# 7         Delaware     5.9      238        72  15.8       Safe
# 8          Florida    15.4      335        80  31.9  Dangerous
# 9          Georgia    17.4      211        60  25.8  Dangerous
# 10          Hawaii     5.3       46        83  20.2       Safe
# 11           Idaho     2.6      120        54  14.2       Safe
# 12        Illinois    10.4      249        83  24.0  Dangerous
# 13         Indiana     7.2      113        65  21.0       Safe
# 14            Iowa     2.2       56        57  11.3       Safe
# 15          Kansas     6.0      115        66  18.0       Safe
# 16        Kentucky     9.7      109        52  16.3  Dangerous
# 17       Louisiana    15.4      249        66  22.2  Dangerous
# 18           Maine     2.1       83        51   7.8       Safe
# 19        Maryland    11.3      300        67  27.8  Dangerous
# 20   Massachusetts     4.4      149        85  16.3       Safe
# 21        Michigan    12.1      255        74  35.1  Dangerous
# 22       Minnesota     2.7       72        66  14.9       Safe
# 23     Mississippi    16.1      259        44  17.1  Dangerous
# 24        Missouri     9.0      178        70  28.2  Dangerous
# 25         Montana     6.0      109        53  16.4       Safe
# 26        Nebraska     4.3      102        62  16.5       Safe
# 27          Nevada    12.2      252        81  46.0  Dangerous
# 28   New Hampshire     2.1       57        56   9.5       Safe
# 29      New Jersey     7.4      159        89  18.8       Safe
# 30      New Mexico    11.4      285        70  32.1  Dangerous
# 31        New York    11.1      254        86  26.1  Dangerous
# 32  North Carolina    13.0      337        45  16.1  Dangerous
# 33    North Dakota     0.8       45        44   7.3       Safe
# 34            Ohio     7.3      120        75  21.4       Safe
# 35        Oklahoma     6.6      151        68  20.0       Safe
# 36          Oregon     4.9      159        67  29.3       Safe
# 37    Pennsylvania     6.3      106        72  14.9       Safe
# 38    Rhode Island     3.4      174        87   8.3       Safe
# 39  South Carolina    14.4      279        48  22.5  Dangerous
# 40    South Dakota     3.8       86        45  12.8       Safe
# 41       Tennessee    13.2      188        59  26.9  Dangerous
# 42           Texas    12.7      201        80  25.5  Dangerous
# 43            Utah     3.2      120        80  22.9       Safe
# 44         Vermont     2.2       48        32  11.2       Safe
# 45        Virginia     8.5      156        63  20.7  Dangerous
# 46      Washington     4.0      145        73  26.2       Safe
# 47   West Virginia     5.7       81        39   9.3       Safe
# 48       Wisconsin     2.6       53        66  10.8       Safe
# 49         Wyoming     6.8      161        60  15.6       Safe

# %% [markdown]
# ### 2)
# Consideramos que es necesario

# %%
from sklearn import preprocessing

estados = data['Unnamed: 0']
seguridad = data['Safety']
data2 = data.drop(['Unnamed: 0', 'Safety'], axis=1)
x = data2.values #returns a numpy array
min_max_scaler = preprocessing.MinMaxScaler()
x_scaled = min_max_scaler.fit_transform(x)
scaled_Data = pd.DataFrame(x_scaled, columns=data2.keys())
scaled_Data['Name states'] = estados
scaled_Data['Safety'] = seguridad
scaled_Data.describe()
scaled_Data
# Out:
#       Murder   Assault  UrbanPop      Rape     Name states     Safety
# 0   0.746988  0.654110  0.440678  0.359173         Alabama  Dangerous
# 1   0.554217  0.746575  0.271186  0.961240          Alaska  Dangerous
# 2   0.439759  0.852740  0.813559  0.612403         Arizona  Dangerous
# 3   0.481928  0.496575  0.305085  0.315245        Arkansas  Dangerous
# 4   0.493976  0.791096  1.000000  0.860465      California  Dangerous
# 5   0.427711  0.544521  0.779661  0.811370        Colorado  Dangerous
# 6   0.150602  0.222603  0.762712  0.098191     Connecticut       Safe
# 7   0.307229  0.660959  0.677966  0.219638        Delaware       Safe
# 8   0.879518  0.993151  0.813559  0.635659         Florida  Dangerous
# 9   1.000000  0.568493  0.474576  0.478036         Georgia  Dangerous
# 10  0.271084  0.003425  0.864407  0.333333          Hawaii       Safe
# 11  0.108434  0.256849  0.372881  0.178295           Idaho       Safe
# 12  0.578313  0.698630  0.864407  0.431525        Illinois  Dangerous
# 13  0.385542  0.232877  0.559322  0.354005         Indiana       Safe
# 14  0.084337  0.037671  0.423729  0.103359            Iowa       Safe
# 15  0.313253  0.239726  0.576271  0.276486          Kansas       Safe
# 16  0.536145  0.219178  0.338983  0.232558        Kentucky  Dangerous
# 17  0.879518  0.698630  0.576271  0.385013       Louisiana  Dangerous
# 18  0.078313  0.130137  0.322034  0.012920           Maine       Safe
# 19  0.632530  0.873288  0.593220  0.529716        Maryland  Dangerous
# 20  0.216867  0.356164  0.898305  0.232558   Massachusetts       Safe
# 21  0.680723  0.719178  0.711864  0.718346        Michigan  Dangerous
# 22  0.114458  0.092466  0.576271  0.196382       Minnesota       Safe
# 23  0.921687  0.732877  0.203390  0.253230     Mississippi  Dangerous
# 24  0.493976  0.455479  0.644068  0.540052        Missouri  Dangerous
# 25  0.313253  0.219178  0.355932  0.235142         Montana       Safe
# 26  0.210843  0.195205  0.508475  0.237726        Nebraska       Safe
# 27  0.686747  0.708904  0.830508  1.000000          Nevada  Dangerous
# 28  0.078313  0.041096  0.406780  0.056848   New Hampshire       Safe
# 29  0.397590  0.390411  0.966102  0.297158      New Jersey       Safe
# 30  0.638554  0.821918  0.644068  0.640827      New Mexico  Dangerous
# 31  0.620482  0.715753  0.915254  0.485788        New York  Dangerous
# 32  0.734940  1.000000  0.220339  0.227390  North Carolina  Dangerous
# 33  0.000000  0.000000  0.203390  0.000000    North Dakota       Safe
# 34  0.391566  0.256849  0.728814  0.364341            Ohio       Safe
# 35  0.349398  0.363014  0.610169  0.328165        Oklahoma       Safe
# 36  0.246988  0.390411  0.593220  0.568475          Oregon       Safe
# 37  0.331325  0.208904  0.677966  0.196382    Pennsylvania       Safe
# 38  0.156627  0.441781  0.932203  0.025840    Rhode Island       Safe
# 39  0.819277  0.801370  0.271186  0.392765  South Carolina  Dangerous
# 40  0.180723  0.140411  0.220339  0.142119    South Dakota       Safe
# 41  0.746988  0.489726  0.457627  0.506460       Tennessee  Dangerous
# 42  0.716867  0.534247  0.813559  0.470284           Texas  Dangerous
# 43  0.144578  0.256849  0.813559  0.403101            Utah       Safe
# 44  0.084337  0.010274  0.000000  0.100775         Vermont       Safe
# 45  0.463855  0.380137  0.525424  0.346253        Virginia  Dangerous
# 46  0.192771  0.342466  0.694915  0.488372      Washington       Safe
# 47  0.295181  0.123288  0.118644  0.051680   West Virginia       Safe
# 48  0.108434  0.027397  0.576271  0.090439       Wisconsin       Safe
# 49  0.361446  0.397260  0.474576  0.214470         Wyoming       Safe

# %% [markdown]
# ### 3)

# %%
import numpy as np
from sklearn.cluster import KMeans
from sklearn.cluster import AgglomerativeClustering
from sklearn.metrics import davies_bouldin_score
from sklearn.datasets.samples_generator import make_blobs
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

# %%
# Eliminamos las variables que no vamos a tener en cuenta.
cluster_data = scaled_Data.drop(['Safety', 'UrbanPop', 'Name states'], axis=1)

# %%
def plot_clusters(X, labels=None, centers=None):
    """ Función auxiliar para pintar los puntos de los clusters y, optativamente, sus centros.
    :param X: array de puntos de dos dimensiones (array de array de enteros)
    :param labels: cluster al que pertenece cada punto (array de enteros)
    :param centers: coordenadas de los centroides de los clusters (array de array de enteros)
    """
    
    colors = ['r','g','b','c','y','k','w','m',]
    fig = plt.figure(figsize=(8,8))
    
    # Los dos primeros parámetros de la función scatter son las coordenadas de los puntos,
    # el parámetro 'c' indica la clase asignada de cada punto, y 'cmap' se usa para colorear 
    # las distintas clases
    plt.scatter(X[:,0], X[:,1], c=labels, cmap=ListedColormap(colors))
    
    # Pintar los centroides de los clusters
    if centers is not None:
        plt.scatter(centers[:,0], centers[:,1], marker="x", color='k', s=150, linewidths = 5, zorder=10)
        
    plt.show()

# %%
K_MAX = 8
davies_boulding = np.zeros(K_MAX-2)
for k in range(2, K_MAX): 
    km = KMeans(init='random', n_clusters=k, random_state=333)
    km.fit(cluster_data)
    plot_clusters(cluster_data.values, km.labels_, km.cluster_centers_)
    
    davies_boulding[k-2] = davies_bouldin_score(cluster_data, km.labels_)

# %%
plt.plot(range(2, K_MAX), davies_boulding)
plt.title('Grafica de calidad de los cluster.')
# Out:
# Text(0.5, 1.0, 'Grafica de calidad de los cluster.')

# %%
K_MAX = 8
davies_boulding = np.zeros(K_MAX-2)
for k in range(2, K_MAX): 
    ag = AgglomerativeClustering(n_clusters=k, linkage='ward', affinity='euclidean')
    ag.fit(cluster_data)
    plot_clusters(cluster_data.values, ag.labels_)
    
    davies_boulding[k-2] = davies_bouldin_score(cluster_data, ag.labels_)

# %%
plt.plot(range(2, K_MAX), davies_boulding)
plt.title('Grafica de calidad de los cluster.')
# Out:
# Text(0.5, 1.0, 'Grafica de calidad de los cluster.')

# %%
ag = AgglomerativeClustering(n_clusters=2, linkage='ward', affinity='euclidean')
ag.fit(cluster_data)

km = KMeans(init='random', n_clusters=2, random_state=333)
km.fit(cluster_data)

#cluster_data['cluster_jer'] = ag.labels_
cluster_data['cluster_kM'] = km.labels_

# %%
cluster_data = cluster_data.drop(['cluster_kM'], axis=1)

# %%
cluster_data.head()
# Out:
#      Murder   Assault      Rape
# 0  0.746988  0.654110  0.359173
# 1  0.554217  0.746575  0.961240
# 2  0.439759  0.852740  0.612403
# 3  0.481928  0.496575  0.315245
# 4  0.493976  0.791096  0.860465

# %%
import seaborn as sns
sns.pairplot(cluster_data, hue='cluster_kM', vars=['Murder', 'Assault', 'Rape'])

# %%
from scipy.cluster.hierarchy import dendrogram

def plot_dendrogram(model, **kwargs):

    # Children of hierarchical clustering
    children = model.children_

    # Distances between each pair of children
    # Since we don't have this information, we can use a uniform one for plotting
    distance = np.arange(children.shape[0])

    # The number of observations contained in each cluster level
    no_of_observations = np.arange(2, children.shape[0]+2)

    # Create linkage matrix and then plot the dendrogram
    linkage_matrix = np.column_stack([children, distance, no_of_observations]).astype(float)

    # Plot the corresponding dendrogram
    dendrogram(linkage_matrix, **kwargs)
    


ag = AgglomerativeClustering(n_clusters=3, linkage='ward', affinity='euclidean')
ag.fit(cluster_data)

# Dibujar los primeros 5 niveles del árbol
levels = 5
plot_dendrogram(ag, p=levels, truncate_mode='level')

# Árbol completo
#plot_dendrogram(ag)
